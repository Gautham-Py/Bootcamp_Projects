# %%
### import sys
### !{sys.executable} -m pip install pyautogui

# %%
### !{sys.executable} -m pip install pillow

# %%
### !{sys.executable} -m pip install mss

# %% [markdown]
# #### 1_st Option

# %%
import pyautogui

# %%
myscreen1 = pyautogui.screenshot()
myscreen1.save("Screen_1.jpg"); myscreen1
# Out:
# <PIL.Image.Image image mode=RGB size=1360x768 at 0x2320EFD9A00>

# %% [markdown]
# ### 2nd_Option

# %%
from PIL import ImageGrab

# %%
myscreen = ImageGrab.grab()
myscreen.save("Screen_PIL.png")

# %%
myscreen
# Out:
# <PIL.Image.Image image mode=RGB size=1360x768 at 0x2320EFD9940>

# %% [markdown]
# ## Option for Mutiple SCreens

# %%
from mss import mss

# %%
### for 2 monitors:

for i in range(1,3):
    mss().shot(mon=i)
